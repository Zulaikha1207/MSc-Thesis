# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\.libs\libopenblas.JPIJNSWNNAN3CE6LLI5FWSPHUT2VXMTH.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
def read_dat(filename):
    df1 = pd.read_csv(filename, sep ='\t', index_col=False)
    df1.columns = ['Start_Date','Start_Time','End_Date','End_Time', 'Average_IBI_msec', 'SDNN_msec', 'Min_IBI_msec', 'Max_IBI_msec',
               'Average_HR_bpm', 'StdDev_HR_bpm', 'Min_HR_bpm', 'Max_HR_bpm', 'RMSSD_msec', 
               'Average_Mot_mg', 'LF_ms', 'HF_ms', 'Average_X_Motility_mg', 'Average_Y_Motility_mg',
               'Average_Z_Motility_mg','Label_Duration_s','Respiration_Rate_bpm', 'houding','activiteit','houding_Code','activiteit_Code', 'Unnamed']
    #combine start date and start time and set to datetime
    df1['Start'] = pd.to_datetime(df1['Start_Date'] + ' ' + df1['Start_Time'])
    #combine end date and end time and set to datetime
    df1['End'] = pd.to_datetime(df1['End_Date'] + ' ' + df1['End_Time'])
    #remove unecessary columns
    df1 = df1.drop(['Start_Date', 'Start_Time', 'End_Date', 'End_Time', 'houding_Code', 'activiteit_Code', 'Unnamed'], axis = 1)
    #Remove first row
    df1 = df1.iloc[1:]
    df1.rename(columns={'activiteit': 'activity', 'houding': 'posture'}, inplace=True)
    #remove space from posture labels
    df1['posture'] = df1['posture'].str.replace(' ', '')
    #remove space from posture labels
    df1['activity'] = df1['activity'].str.replace(' ', '')
    df1.posture = df1.posture.replace(['liggen','zitten+staan+lopen', 'staan+lopen','zitten+staan','zitten', 'lopen', 'staan'],
                                            ['lying_down', 'sitting+standing+walking', 'standing+walking', 'sitting+standing', 'sitting', 'walking', 'standing'])
    #cols = ['Average_IBI_msec', 'Min_IBI_msec', 'Max_IBI_msec', 'SDNN_msec', 'Average_Mot_mg', 'posture', 'activity']
    #df1 = df1[cols]
    return df1

# %%
df1 = read_dat('3m2S3_g1_m4_dubbelcheck_permin.txt')
df2 = read_dat('15m3s15_g1_m3_HRV_deel1_dubbelcheck_copy_permin.txt')
df3 = read_dat('13m1s13_g1_m1_HRV_deel1_dubbelcheck_copy_permin.txt')
df4 = read_dat('22m1HRV_s22_g1_m1_Dubbelcheck_copy_permin.txt')
df5 = read_dat('37m1HRV_s37_g2_m1klaar_permin.txt')
df6 = read_dat('13m1s13_g1_m1_HRV_deel2_dubbelcheck_copy_permin.txt')
df7 = read_dat('15m3s15_g1_m3_HRV_deel2_dubbelcheck_copy_permin.txt')
df8 = read_dat('HRV_s222_g1_m1_dubbelcheck_permin.txt')
df9 = read_dat('56m1s56_g1_m1_HRV_dubbelgechecktcopy_permin.txt')
df10 = read_dat('57m1HRV_s57_g1_m1_Dubbelcheck_copy_permin.txt')
df11 = read_dat('13m2s13_g1_m2_HRV_deel1_dubbelcheck_copy_permin.txt')
df12 = read_dat('67m1HRV67_g1_m1klaar_permin.txt')
df13 = read_dat('108m1HRV_s108_g1_m1klaar_permin.txt')
df14 = read_dat('57m2HRV_S57_g1_m2_Dubbelcheck_copy_permin.txt')
df15 = read_dat('140m2s140_g2_m1(m2)_HRV_dubbelcheck_copy_permin.txt')
df16 = read_dat('147m1s147_g2_m1_dubbelcheck_permin.txt')
df17 = read_dat('156m2s156_g2_m2_dubbelcheck_permin.txt')
df18 = read_dat('57m3S57_g1_m3klaar_permin.txt')
df19 = read_dat('56m2s56_g1_m2_HRV_dubbelcheck_copy_permin.txt')
df20 = read_dat('22m2HRV_s22_g1_m2_Dubbelcheck_copy_permin.txt')
df21 = read_dat('13m4HRV_13_g1_m4_dubbelcheck_permin.txt')
df22 = read_dat('15m4HRV_s15_g1_m4_dubbelcheck_permin.txt')
df23 = read_dat('HRV_208_g2_m2_dubbelcheck_permin.txt')
df24 = read_dat('HRV_s3_g1_m2_dubbelcheck_permin.txt')
df25 = read_dat('HRV_s15_g1_m2_dubbelcheck_permin.txt')
df26 = read_dat('67m4HRV_S67_g1_m4_dubbelcheck_permin.txt')
df27 = read_dat('HRV_s56_g1_m4_dubbelcheck_permin.txt')
df28 = read_dat('HRV_s108_g1_m2_dubbelcheck_permin.txt')
df29 = read_dat('HRV_s156_g2_m3_dubbelcheck_permin.txt')
df30 = read_dat('67m2HRV_s67_g1_m2klaar_permin.txt')
df31 = read_dat('13m2s13_g1_m2_HRV_deel2_dubbelcheck_copy_permin.txt')
df32 = read_dat('HRV_s207_g2_m2_dubbelcheck_permin.txt')
df33 = read_dat('147m2s147_g2_m2_dubbelcheck_permin.txt')
df34 = read_dat('HRV_s3_g1_m3_dubbelcheck_permin.txt')
df35 = read_dat('HRV_208_g2_m3_dubbelcheck_permin.txt')
df36 = read_dat('147m3S147_g2_m3klaar_permin.txt')

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10,
          df11, df12, df13, df14, df15, df16, df17, df18, df19, df20,
          df21, df22, df23, df24, df25, df26, df27, df28, df29, df30,
          df31, df32, df33, df34, df35, df36], ignore_index=True,axis=0)

# %%
df.posture.value_counts()
# Out:
# -9999                       30490
# lying_down                  15064
# sitting                       480
# sitting+standing+walking      183
# sitting+standing              109
# walking                       108
# standing+walking              107
# standing                       14
# anders                          4
# zitten+liggen                   4
# Name: posture, dtype: int64

# %%
df.posture = df.posture.replace(['zitten+liggen'], ['sitting+lying_down'])
df.drop(df.loc[df['posture']== '-9999'].index, inplace=True)
df.drop(df.loc[df['Average_HR_bpm']== -9999].index, inplace=True)
df = df.reset_index()
df = df.drop('index', axis=1)
df
# Out:
#        Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  \
# 0                913.15      55.21         755.0        1030.0
# 1                973.97      82.89         776.0        1126.0
# 2                944.39      53.90         811.0        1035.0
# 3                953.98      77.73         785.0        1189.0
# 4                784.87      59.95         682.0         887.0
# ...                 ...        ...           ...           ...
# 16056            986.17      24.37         927.0        1055.0
# 16057            994.73      26.28         940.0        1076.0
# 16058            964.08      20.94         906.0        1006.0
# 16059           1005.14      30.72         946.0        1097.0
# 16060            974.20      18.11         936.0        1014.0
#
#        Average_HR_bpm  StdDev_HR_bpm  Min_HR_bpm  Max_HR_bpm  RMSSD_msec  \
# 0               65.95           4.17       58.25       79.47       24.98
# ...

# %%
df.describe()
# Out:
#        Average_IBI_msec     SDNN_msec  Min_IBI_msec  Max_IBI_msec  \
# count      16061.000000  16061.000000  16061.000000  16061.000000
# mean         944.871737     64.138389    816.313928   1100.877965
# std          121.733355     38.249253    132.335137    167.795456
# min          449.860000      6.550000    201.000000    465.000000
# 25%          866.330000     37.470000    746.000000    988.000000
# 50%          945.160000     53.650000    828.000000   1088.000000
# 75%         1033.160000     79.380000    903.000000   1196.000000
# max         1268.570000    405.130000   1160.000000   2710.000000
#
#        Average_HR_bpm  StdDev_HR_bpm    Min_HR_bpm    Max_HR_bpm  \
# count    16061.000000   16061.000000  16061.000000  16061.000000
# mean        65.116091       4.632651     55.780928     76.237385
# std          9.555464       3.649206      8.727086     19.308549
# min         47.420000       0.730000     22.140000     51.720000
# ...

# %%
def activity_selection(df_ecg):
    df_ecg.loc[(df_ecg['activity']=='AdministrativeWork') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='RecreationalActivities(Active)') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='HouseholdActivities') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='DeskWork') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='WatchingTV') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='Transportation(Active)') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='Eating/Drinking') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='Reading/Internet/OtherRecreativePCUse') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='Telephone/TalkingPrivate') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='RecreationalActivities(Passive)') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='RecreationalActivities') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='Transportation(Active)') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='Transportation(Passive)') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='Intervention') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.loc[(df_ecg['activity']=='PhysicalWork') & (df_ecg['posture'] != 'standing+walking'), ['posture']] = 'standing+walking'
    df_ecg.loc[(df_ecg['activity']=='Telephone/TalkingAtWork') & (df_ecg['posture'] != 'sitting'), ['posture']] = 'sitting'
    df_ecg.drop(df_ecg.loc[df_ecg['activity']== 'Unknown'].index, inplace=True)
    df_ecg = df_ecg.loc[(df_ecg['posture'] == 'sitting') | (df_ecg['posture'] == 'standing+walking')]
    df_ecg = df_ecg.reset_index()
    df_ecg = df_ecg.drop('index', axis=1)
    return df_ecg

# %%
newd = activity_selection(df)
newd
# Out:
#      Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0              913.15      55.21         755.0        1030.0           65.95
# 1              973.97      82.89         776.0        1126.0           62.04
# 2              944.39      53.90         811.0        1035.0           63.75
# 3              953.98      77.73         785.0        1189.0           63.31
# 4              784.87      59.95         682.0         887.0           76.89
# ..                ...        ...           ...           ...             ...
# 934            908.54      80.91         734.0        1069.0           66.57
# 935            700.65      20.33         651.0         749.0           85.71
# 936            701.38      24.96         666.0         778.0           85.65
# 937            760.26      28.33         693.0         820.0           79.03
# 938            760.37      29.73         687.0         815.0           79.03
#
# ...

# %%
sns.boxplot(x="activity", y="Average_HR_bpm", data=df_new)
sns.displot(df_new, x="Average_HR_bpm", hue="posture", element="step")
sns.displot(df_new, x="Average_HR_bpm", col="activity")
sns.displot(df_new, x="Average_X_Motility_mg", col="posture")
df_new['Average_HR_bpm'].hist(by=df_new['posture'])
# Out:
# array([<AxesSubplot:title={'center':'sitting'}>,
#        <AxesSubplot:title={'center':'standing+walking'}>], dtype=object)

# %%
df_new.activity.value_counts().index
# Out:
# Index(['DeskWork', 'HouseholdActivities', 'Transportation(Active)',
#        'Eating/Drinking', 'Intervention', 'RecreationalActivities(Active)',
#        'RecreationalActivities(Passive)',
#        'Reading/Internet/OtherRecreativePCUse', 'Telephone/TalkingAtWork',
#        'WatchingTV', 'Telephone/TalkingPrivate', 'RecreationalActivities',
#        'PhysicalWork', 'Transportation(Passive)', 'AdministrativeWork'],
#       dtype='object')

# %%
act1 = ['DeskWork', 'HouseholdActivities', 'Transportation(Active)',
       'Eating/Drinking', 'Intervention', 'RecreationalActivities(Active)',
       'RecreationalActivities(Passive)']
act1
# Out:
# ['DeskWork',
#  'HouseholdActivities',
#  'Transportation(Active)',
#  'Eating/Drinking',
#  'Intervention',
#  'RecreationalActivities(Active)',
#  'RecreationalActivities(Passive)']

# %% [markdown]
# ### Remove outliers

# %%
plt.figure(figsize=(25, 6))
ax = sns.boxplot(x="activity", y="Average_HR_bpm", data=df_new1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11328/1885620231.py in <module>
#       1 plt.figure(figsize=(25, 6))
# ----> 2 ax = sns.boxplot(x="activity", y="Average_HR_bpm", data=df_new1)
#
# NameError: name 'df_new1' is not defined

# %%
plt.rcParams['figure.dpi'] = 200
plt.figure(figsize=(11, 10))
ax = sns.boxplot(x="Average_HR_bpm", y="activity", data=newd, orient="h", width=0.4)
plt.xlabel('Average heart rate (bpm)', fontsize=12);
plt.xlim(40, 150)
#plt.savefig('outlier detection for all activities.png',  bbox_inches='tight')
#plt.title('Distribution of heart rate by activities (outlier detection)', fontsize=14)
# Out:
# (40.0, 150.0)

# %%
plt.rcParams['figure.dpi'] = 200
plt.figure(figsize=(11, 10))
ax = sns.boxplot(x="Average_Mot_mg", y="activity", data=df_new, orient="h", width=0.4)
plt.xlabel('Average magnitude acceleration', fontsize=12);
plt.xlim(-10, 150)
plt.savefig('after outlier removal for all activities wrt average magnitude acc.png',  bbox_inches='tight')
#plt.title('Distribution of heart rate by activities (outlier detection)', fontsize=14)

# %%
df_new.activity.value_counts()
# Out:
# DeskWork                                 205
# HouseholdActivities                      147
# Transportation(Active)                   129
# Eating/Drinking                          108
# Intervention                              60
# RecreationalActivities(Active)            55
# RecreationalActivities(Passive)           41
# Reading/Internet/OtherRecreativePCUse     39
# Telephone/TalkingAtWork                   39
# WatchingTV                                34
# Telephone/TalkingPrivate                  28
# RecreationalActivities                    25
# PhysicalWork                              16
# Transportation(Passive)                    9
# AdministrativeWork                         4
# Name: activity, dtype: int64

# %%
percentile25 = newd.loc[newd['activity'] == 'Transportation(Active)', 'Average_HR_bpm'].quantile(0.25)
percentile75 = newd.loc[newd['activity'] == 'Transportation(Active)', 'Average_HR_bpm'].quantile(0.75)

# %%
iqr = percentile75 - percentile25
iqr

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
upper_limit
# Out:
# 124.35999999999999

# %%
newd[(newd['activity'] == 'Transportation(Active)') & ( newd['Average_HR_bpm'] < lower_limit )]
# Out:
# Empty DataFrame
# Columns: [Average_IBI_msec, SDNN_msec, Min_IBI_msec, Max_IBI_msec, Average_HR_bpm, StdDev_HR_bpm, Min_HR_bpm, Max_HR_bpm, RMSSD_msec, Average_Mot_mg, LF_ms, HF_ms, Average_X_Motility_mg, Average_Y_Motility_mg, Average_Z_Motility_mg, Label_Duration_s, Respiration_Rate_bpm, posture, activity, Start, End]
# Index: []
#
# [0 rows x 21 columns]

# %%
#newd = newd[~((newd['activity'] == 'Transportation(Active)') & ( newd['Average_HR_bpm'] > upper_limit ))]
newd = newd[~((newd['activity'] == 'Transportation(Active)') & ( newd['Average_HR_bpm'] < lower_limit ))]

newd = newd.reset_index()
newd = newd.drop('index', axis=1)
newd
# Out:
#      Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0              913.15      55.21         755.0        1030.0           65.95
# 1              973.97      82.89         776.0        1126.0           62.04
# 2              944.39      53.90         811.0        1035.0           63.75
# 3              953.98      77.73         785.0        1189.0           63.31
# 4              784.87      59.95         682.0         887.0           76.89
# ..                ...        ...           ...           ...             ...
# 791            908.54      80.91         734.0        1069.0           66.57
# 792            700.65      20.33         651.0         749.0           85.71
# 793            701.38      24.96         666.0         778.0           85.65
# 794            760.26      28.33         693.0         820.0           79.03
# 795            760.37      29.73         687.0         815.0           79.03
#
# ...

# %%
newd.to_csv('train_permin_vudams_without_outliers_magnitude_acc_and_heartRate.csv', index= False)

# %% [markdown]
# ### data without outliers

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
newd = pd.read_csv('train_permin_vudams_without_outliers.csv')
newd
# Out:
#      Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0              913.15      55.21         755.0        1030.0           65.95
# 1              973.97      82.89         776.0        1126.0           62.04
# 2              944.39      53.90         811.0        1035.0           63.75
# 3              953.98      77.73         785.0        1189.0           63.31
# 4              784.87      59.95         682.0         887.0           76.89
# ..                ...        ...           ...           ...             ...
# 921            908.54      80.91         734.0        1069.0           66.57
# 922            700.65      20.33         651.0         749.0           85.71
# 923            701.38      24.96         666.0         778.0           85.65
# 924            760.26      28.33         693.0         820.0           79.03
# 925            760.37      29.73         687.0         815.0           79.03
#
# ...

# %%
newd.describe()
# Out:
#        Average_IBI_msec   SDNN_msec  Min_IBI_msec  Max_IBI_msec  \
# count        926.000000  926.000000    926.000000    926.000000
# mean         757.620810   55.994276    647.881210    896.977322
# std          120.796362   24.596199    105.012797    148.363864
# min          449.860000    6.550000    213.000000    465.000000
# 25%          676.880000   38.397500    572.000000    804.000000
# 50%          750.405000   53.090000    642.000000    900.500000
# 75%          844.235000   68.832500    712.000000    996.750000
# max         1154.780000  184.190000    973.000000   1730.000000
#
#        Average_HR_bpm  StdDev_HR_bpm  Min_HR_bpm  Max_HR_bpm  RMSSD_msec  \
# count      926.000000     926.000000  926.000000  926.000000  926.000000
# mean        81.861533       6.008305   68.914438   95.271922   33.590011
# std         13.903094       2.897893   12.769497   17.592784   18.719840
# min         52.500000       1.510000   34.680000   61.660000    2.400000
# ...

# %%
newd.loc[newd['Average_Mot_mg']== -9999]
# Out:
#      Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 472            844.07     117.02         669.0        1367.0           72.25
# 473            782.09      78.73         633.0         944.0           77.50
# 474            855.91      96.59         717.0        1205.0           70.89
# 475            830.92      87.73         665.0        1158.0           72.95
# 476            797.81      89.62         608.0         976.0           76.24
# 477            768.17      66.46         592.0         917.0           78.74
# 478            779.17      32.08         706.0         866.0           77.13
# 479            764.14      42.82         697.0         883.0           78.76
# 480            900.62      78.92         768.0        1234.0           67.09
# 481            892.73      59.04         783.0        1046.0           67.49
# 482            873.21      67.76         709.0        1047.0           69.12
# ...

# %%
newd.drop(newd.loc[newd['Average_Mot_mg']== -9999].index, inplace=True)
newd = newd.reset_index()
newd = newd.drop('index', axis=1)
newd
# Out:
#      Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0              913.15      55.21         755.0        1030.0           65.95
# 1              973.97      82.89         776.0        1126.0           62.04
# 2              944.39      53.90         811.0        1035.0           63.75
# 3              953.98      77.73         785.0        1189.0           63.31
# 4              784.87      59.95         682.0         887.0           76.89
# ..                ...        ...           ...           ...             ...
# 922            908.54      80.91         734.0        1069.0           66.57
# 923            700.65      20.33         651.0         749.0           85.71
# 924            701.38      24.96         666.0         778.0           85.65
# 925            760.26      28.33         693.0         820.0           79.03
# 926            760.37      29.73         687.0         815.0           79.03
#
# ...

# %%
newd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 939 entries, 0 to 938
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Average_IBI_msec       939 non-null    float64
#  1   SDNN_msec              939 non-null    float64
#  2   Min_IBI_msec           939 non-null    float64
#  3   Max_IBI_msec           939 non-null    float64
#  4   Average_HR_bpm         939 non-null    float64
#  5   StdDev_HR_bpm          939 non-null    float64
#  6   Min_HR_bpm             939 non-null    float64
#  7   Max_HR_bpm             939 non-null    float64
#  8   RMSSD_msec             939 non-null    float64
#  9   Average_Mot_mg         939 non-null    float64
#  10  LF_ms                  939 non-null    int64
#  11  HF_ms                  939 non-null    int64
#  12  Average_X_Motility_mg  939 non-null    float64
#  13  Average_Y_Motility_mg  939 non-null    float64
# ...

# %%
df_pivot_std = pd.pivot_table(
df_bar,
values="StdDev_HR_bpm",
index="posture",
columns="activity",
aggfunc=np.std
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11328/3871975711.py in <module>
#       1 df_pivot_std = pd.pivot_table(
# ----> 2 df_bar,
#       3 values="StdDev_HR_bpm",
#       4 index="posture",
#       5 columns="activity",
#
# NameError: name 'df_bar' is not defined

# %%
plt.rcParams['figure.dpi'] = 200
df_bar = newd.copy()

# Draw bar plot
df_pivot = pd.pivot_table(
df_bar,
values="Average_HR_bpm",
index="posture",
columns="activity",
aggfunc=np.mean
)

# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar", width = 0.7, yerr = df_pivot_std,  cmap = 'tab20',  capsize=3)
plt.legend(loc=2, prop={'size': 8})
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(18, 10)
# Change the axes labels
ax.set_ylim(40, 150)
ax.set_yticks(np.arange(40, 150, step=10))
ax.set_xlabel("New class labels")
ax.set_ylabel("Average heart rate (bpm)")      
ax.xaxis.grid()
#ax.grid(which='major', axis='y', linestyle='-')
# Save image and return fig (don't change this part)
fig.savefig('after outlier removal heartrate distribution by activity.png',  bbox_inches='tight')
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# ...

# %%
df_bar = newd.copy()

# Draw bar plot
df_pivot = pd.pivot_table(
df_bar,
values="Average_Mot_mg",
index="posture",
columns="activity",
aggfunc=np.mean
)

# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar", width = 0.7, cmap = 'tab20',  capsize=3)
plt.legend(loc=2, prop={'size': 8})
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(18, 10)
# Change the axes labels
ax.set_ylim(0, 70)
ax.set_yticks(np.arange(0, 70, step=10))
ax.set_xlabel("New class labels")
ax.set_ylabel("Average heart rate (bpm)")      
ax.xaxis.grid()
#ax.grid(which='major', axis='y', linestyle='-')
# Save image and return fig (don't change this part)
#fig.savefig('after activity selection.png',  bbox_inches='tight')

# %%
plt.rcParams['figure.dpi'] = 80
sns.catplot(x="posture", y="Average_X_Motility_mg", data=newd, kind='violin')

# %%
plt.rcParams['figure.dpi'] = 80
sns.catplot(x="posture", y="Average_Mot_mg", data=newd, kind='violin')

# %%
sns.catplot(x="posture", y="Average_HR_bpm", data=newd, kind='violin')

# %%
plt.rcParams['figure.dpi'] = 100
plt.figure(figsize=(18, 6))
sns.catplot(x="posture", y="Average_HR_bpm", hue = 'activity', data=newd, aspect = 10/6, kind='violin')
#plt.legend(title='Activity', fontsize=4)

# %%
df_bar = df_new.copy()

# Draw bar plot
df_pivot = pd.pivot_table(
df_bar,
values="StdDev_HR_bpm",
index="posture",
columns="activity",
aggfunc=np.mean
)

# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar", width = 0.7, cmap = 'tab20',  capsize=3)
plt.legend(loc=2, prop={'size': 8})
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(18, 10)
# Change the axes labels
ax.set_ylim(0, 40)
ax.set_yticks(np.arange(0, 40, step=10))
ax.set_xlabel("New class labels")
ax.set_ylabel("Average heart rate (bpm)")      
ax.xaxis.grid()
#ax.grid(which='major', axis='y', linestyle='-')
# Save image and return fig (don't change this part)
#fig.savefig('after activity selection.png',  bbox_inches='tight')

# %%
#df1['Average_HR_bpm'].groupby("posture", as_index=False).shift(-1)
newd['lagg_HR'] = newd['Average_HR_bpm'].groupby(newd['posture']).shift(1)

# %%
newd = newd.fillna(method='bfill')

# %%
newd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Average_IBI_msec       796 non-null    float64
#  1   SDNN_msec              796 non-null    float64
#  2   Min_IBI_msec           796 non-null    float64
#  3   Max_IBI_msec           796 non-null    float64
#  4   Average_HR_bpm         796 non-null    float64
#  5   StdDev_HR_bpm          796 non-null    float64
#  6   Min_HR_bpm             796 non-null    float64
#  7   Max_HR_bpm             796 non-null    float64
#  8   RMSSD_msec             796 non-null    float64
#  9   Average_Mot_mg         796 non-null    float64
#  10  LF_ms                  796 non-null    int64
#  11  HF_ms                  796 non-null    int64
#  12  Average_X_Motility_mg  796 non-null    float64
#  13  Average_Y_Motility_mg  796 non-null    float64
# ...

# %%
cols = [ 'Average_Mot_mg', 'Average_HR_bpm', 'lagg_HR']
dfx = newd[cols]
dfx
# Out:
#      Average_Mot_mg  Average_HR_bpm  lagg_HR
# 0              0.53           65.95    65.95
# 1              1.89           62.04    65.95
# 2              1.06           63.75    62.04
# 3              0.24           63.31    63.75
# 4              1.77           76.89    63.31
# ..              ...             ...      ...
# 791            2.01           66.57    63.78
# 792            0.35           85.71    66.57
# 793            0.59           85.65    85.71
# 794            0.06           79.03    85.65
# 795            0.06           79.03    79.03
#
# [796 rows x 3 columns]

# %%
y = newd.pop('posture')
y
# Out:
# 0      sitting
# 1      sitting
# 2      sitting
# 3      sitting
# 4      sitting
#         ...
# 791    sitting
# 792    sitting
# 793    sitting
# 794    sitting
# 795    sitting
# Name: posture, Length: 796, dtype: object

# %%
x = np.array(dfx)
x.shape
# Out:
# (796, 3)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
import imblearn
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.utils.class_weight import compute_class_weight

# %% [raw]
# def lr_model(X, y):
#     ts_cv = KFold(n_splits = 4, shuffle = False)
#     all_splits = list(ts_cv.split(x))
#     # n-fold cross-validation
#     for i in range(0, len(all_splits)):
#         train_x = X[all_splits[i][0]]
#         test_x = X[all_splits[i][1]]
#         train_y = y[all_splits[i][0]]
#         test_y = y[all_splits[i][1]]
#
#         # standardization
#         scaler = StandardScaler()
#         scaler.fit(train_x)
#         X_train_data_lr_1 = scaler.transform(train_x)
#         X_test_data_lr_1 = scaler.transform(test_x)
#
#         #SMOTE for data imbalance
#         #smote = SMOTE(sampling_strategy='not majority')
#         #X_train_data_lr_1, y_train_1  = smote.fit_resample(X_train_data_lr_1, train_y)
#         #logistic regression model
#         lr = LogisticRegression(random_state=55, class_weight = 'balanced')
#         lr.fit(X_train_data_lr_1, train_y)
#         y_pred_train = lr.predict(X_train_data_lr_1)
#         y_pred = lr.predict(X_test_data_lr_1)
#         accuracy_tr, f1_tr = training_evaluation(y_pred_train, train_y, i)
#         accuracy, f1 = validation_evaluation(y_pred, test_y, i)
#     return accuracy_tr, f1_tr, accuracy, f1

# %%
plt.rcParams['figure.dpi'] = 70

def training_evaluation(ypred, ytrue, i, accuracy = [], score = []):
    # compute accuracy by averaging the predicted class over the whole time series
    m1 = f1_score(ytrue, ypred, average='weighted', zero_division = 0)
    score.append(m1)
    a1 =  accuracy_score(ytrue, ypred)
    accuracy.append(a1)
    print(f"\n -------------Classification Report for Training CV #{i}-------------\n")
    print(classification_report(ytrue, ypred))

    labels = ['sitting', 'standing+walking']
    confusion_matrix_1 = confusion_matrix(ytrue, ypred)
    sns.heatmap(confusion_matrix_1, xticklabels=labels, yticklabels=labels, annot=True,linewidths = 0.1, fmt='d', cmap = 'YlGnBu')
    plt.title(f'Training confusion matrix for cv #{i}', fontsize = 15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
    return score, accuracy

# %%
plt.rcParams['figure.dpi'] = 70

def validation_evaluation(ypred, ytrue, i, accuracy = [], score = []):
    # compute accuracy by averaging the predicted class over the whole time series
    m1 = f1_score(ytrue, ypred, average='weighted', zero_division = 0)
    score.append(m1)
    a1 =  accuracy_score(ytrue, ypred)
    accuracy.append(a1)
    print(f"\n -------------Classification Report for validation CV #{i}-------------\n")
    print(classification_report(ytrue, ypred))

    labels = ['sitting', 'standing+walking']
    confusion_matrix_1 = confusion_matrix(ytrue, ypred)
    sns.heatmap(confusion_matrix_1, xticklabels=labels, yticklabels=labels, annot=True,linewidths = 0.1, fmt='d', cmap = 'YlGnBu')
    plt.title(f'Validation confusion matrix for cv #{i}', fontsize = 15)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
    return score, accuracy

# %%
kfold = KFold(n_splits=3, shuffle = False)
# Dataframe with misclassified examples
misclf_df = pd.DataFrame(
    {
        'folds' : np.zeros(x.shape[0]), 
        'is_misclassified' : np.zeros(x.shape[0])
    },
)

for i, (train_idx, test_idx) in enumerate(kfold.split(x, y)):

    #get train/test split for current fold
    X_train, y_train = x[train_idx], y[train_idx]
    X_test, y_test = x[test_idx], y[test_idx]

    # standardization
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_data_lr_1 = scaler.transform(X_train)
    X_test_data_lr_1 = scaler.transform(X_test)

        #SMOTE for data imbalance
        #smote = SMOTE(sampling_strategy='not majority')
        #X_train_data_lr_1, y_train_1  = smote.fit_resample(X_train_data_lr_1, train_y)
        #logistic regression model
    lr = LogisticRegression(random_state=55, class_weight = 'balanced')
    lr.fit(X_train_data_lr_1, y_train)
    y_pred_train = lr.predict(X_train_data_lr_1)
    y_pred = lr.predict(X_test_data_lr_1)

    # write results
    misclf_df.loc[test_idx, 'folds'] = i
    misclf_df.loc[test_idx, 'is_misclassified'] = lr.predict(X_test_data_lr_1) != y_test
    accuracy_tr, f1_tr = training_evaluation(y_pred_train, y_train, i)
    acc_val, f1_val = validation_evaluation(y_pred, y_test, i)
print('Training mean accuracy', np.mean(accuracy_tr))
print('Training mean f1-score', np.mean(f1_tr))
print('Validation mean accuracy', np.mean(acc_val))
print('Validation mean f1-score', np.mean(f1_val))
# Out:
#  -------------Classification Report for Training CV #0-------------
#
#                   precision    recall  f1-score   support
#
#          sitting       0.85      0.88      0.87       300
# standing+walking       0.84      0.80      0.82       230
#
#         accuracy                           0.85       530
#        macro avg       0.85      0.84      0.85       530
#     weighted avg       0.85      0.85      0.85       530
#  -------------Classification Report for validation CV #0-------------
#
#                   precision    recall  f1-score   support
#
#          sitting       0.84      0.85      0.84       175
# standing+walking       0.70      0.68      0.69        91
#
#         accuracy                           0.79       266
#        macro avg       0.77      0.77      0.77       266
#     weighted avg       0.79      0.79      0.79       266
#  -------------Classification Report for Training CV #1-------------
#
# ...

# %%
print('Training mean accuracy', np.mean(accuracy_tr))
print('Training mean f1-score', np.mean(f1_tr))
print('Validation mean accuracy', np.mean(acc_val))
print('Validation mean f1-score', np.mean(f1_val))
# Out:
# Training mean accuracy 0.8377834347155273
# Training mean f1-score 0.8386605644095523
# Validation mean accuracy 0.8359872353257056
# Validation mean f1-score 0.8359916743191466

# %%
list1 = y_test.index

# %%
len(y_test)
# Out:
# 265

# %%
y_pred_df = pd.DataFrame(y_pred, columns = {'y_pred'})

# %%
y_pred_df = y_pred_df.set_index(list1)

# %%
y_pred_df
# Out:
#       y_pred
# 531  sitting
# 532  sitting
# 533  sitting
# 534  sitting
# 535  sitting
# ..       ...
# 791  sitting
# 792  sitting
# 793  sitting
# 794  sitting
# 795  sitting
#
# [265 rows x 1 columns]

# %%
pred_posture = y_pred_df.loc[misclf_df.loc[(misclf_df['folds'] == 2.0) & (misclf_df['is_misclassified'] == True)].index, 'y_pred']

# %%
y_test_df = pd.DataFrame(y_test.values, columns = {'y_test'})
y_test_df
# Out:
#       y_test
# 0    sitting
# 1    sitting
# 2    sitting
# 3    sitting
# 4    sitting
# ..       ...
# 260  sitting
# 261  sitting
# 262  sitting
# 263  sitting
# 264  sitting
#
# [265 rows x 1 columns]

# %%
y_test_df = y_test_df.set_index(list1)

# %%
true_posture = y_test_df.loc[misclf_df.loc[(misclf_df['folds'] == 2.0) & (misclf_df['is_misclassified'] == True)].index, 'y_test']
true_posture
# Out:
# 543    standing+walking
# 544    standing+walking
# 568    standing+walking
# 569    standing+walking
# 571    standing+walking
# 576    standing+walking
# 592             sitting
# 593             sitting
# 595             sitting
# 596             sitting
# 597             sitting
# 606    standing+walking
# 607    standing+walking
# 608    standing+walking
# 614    standing+walking
# 615    standing+walking
# 616    standing+walking
# 617    standing+walking
# 627    standing+walking
# 628    standing+walking
# 629    standing+walking
# 637    standing+walking
# 654             sitting
# 670    standing+walking
# 688    standing+walking
# 690    standing+walking
# 691    standing+walking
# 737    standing+walking
# 738    standing+walking
# 739    standing+walking
# 740    standing+walking
# 741    standing+walking
# Name: y_test, dtype: object

# %%
misclf_df.loc[(misclf_df['folds'] == 2.0) & (misclf_df['is_misclassified'] == True)].index
# Out:
# Int64Index([543, 544, 568, 569, 571, 576, 592, 593, 595, 596, 597, 606, 607,
#             608, 614, 615, 616, 617, 627, 628, 629, 637, 654, 670, 688, 690,
#             691, 737, 738, 739, 740, 741],
#            dtype='int64')

# %%
residuals = newd.loc[misclf_df.loc[(misclf_df['folds'] == 2.0) & (misclf_df['is_misclassified'] == True)].index]
residuals = residuals.reset_index()
residuals = residuals.drop('index', axis =1)
residuals['pred_posture'] = pred_posture.values
residuals
# Out:
#     Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0             675.74      55.91         576.0         763.0           89.41
# 1             725.47      54.63         636.0         827.0           83.18
# 2             849.33     136.42         655.0        1322.0           72.30
# 3             643.96      68.48         556.0         837.0           94.15
# 4             824.04     114.22         647.0        1149.0           74.10
# 5             613.53      57.91         497.0         774.0           98.68
# 6             623.33      46.36         542.0         811.0           96.76
# 7             651.96      63.16         555.0         804.0           92.85
# 8             625.54      62.47         554.0         801.0           96.77
# 9             623.58      38.42         557.0         737.0           96.58
# 10            806.41      61.99         665.0         926.0           74.84
# ...

# %%
residuals['true_posture'] = true_posture.values
residuals
# Out:
#     Average_IBI_msec  SDNN_msec  Min_IBI_msec  Max_IBI_msec  Average_HR_bpm  \
# 0             675.74      55.91         576.0         763.0           89.41
# 1             725.47      54.63         636.0         827.0           83.18
# 2             849.33     136.42         655.0        1322.0           72.30
# 3             643.96      68.48         556.0         837.0           94.15
# 4             824.04     114.22         647.0        1149.0           74.10
# 5             613.53      57.91         497.0         774.0           98.68
# 6             623.33      46.36         542.0         811.0           96.76
# 7             651.96      63.16         555.0         804.0           92.85
# 8             625.54      62.47         554.0         801.0           96.77
# 9             623.58      38.42         557.0         737.0           96.58
# 10            806.41      61.99         665.0         926.0           74.84
# ...

# %%
plt.rcParams['figure.dpi'] = 200
sns.set_theme(style='white')
fig = sns.catplot(x="pred_posture", y="Average_HR_bpm",  hue="activity", data=residuals, height=5, s=8)
fig.set( xlabel = "Predicted posture", ylabel = "Average heart rate (bpm)")
fig.set(title='Heart rate of missclassified samples')

# %%
plt.rcParams['figure.dpi'] = 200
sns.set_theme(style='white')
fig = sns.catplot(x="true_posture", y="Average_HR_bpm",  hue="activity", data=residuals, height=5, s=8)
fig.set( xlabel = "True posture", ylabel = "Average heart rate (bpm)")
fig.set(title='Heart rate of missclassified samples')

# %%
plt.rcParams['figure.dpi'] = 150
sns.set_theme(style='white')
fig = sns.catplot(x="true_posture", y="Average_Mot_mg",  hue="activity", data=residuals, height=5, s=8)
fig.set( xlabel = "True posture", ylabel = "Average_X_Motility_mg")
fig.set(title='Average_X_Motility_mg of missclassified samples')

# %%
plt.rcParams['figure.dpi'] = 150
sns.set_theme(style='white')
fig = sns.catplot(x="true_posture", y="Average_Y_Motility_mg",  hue="activity", data=residuals, height=5, s=8)
fig.set( xlabel = "True posture", ylabel = "Average_Y_Motility_mg")
fig.set(title='Average_X_Motility_mg of missclassified samples')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7868/1289955678.py in <module>
# ----> 1 plt.rcParams['figure.dpi'] = 150
#       2 sns.set_theme(style='white')
#       3 fig = sns.catplot(x="true_posture", y="Average_Y_Motility_mg",  hue="activity", data=residuals, height=5, s=8)
#       4 fig.set( xlabel = "True posture", ylabel = "Average_Y_Motility_mg")
#       5 fig.set(title='Average_X_Motility_mg of missclassified samples')
#
# NameError: name 'plt' is not defined

# %%
plt.rcParams['figure.dpi'] = 150
sns.set_theme(style='white')
fig = sns.catplot(x="true_posture", y="Average_Z_Motility_mg",  hue="activity", data=residuals, height=5, s=8)
fig.set( xlabel = "True posture", ylabel = "Average_X_Motility_mg")
fig.set(title='Average_X_Motility_mg of missclassified samples')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7868/218861626.py in <module>
# ----> 1 plt.rcParams['figure.dpi'] = 150
#       2 sns.set_theme(style='white')
#       3 fig = sns.catplot(x="true_posture", y="Average_Z_Motility_mg",  hue="activity", data=residuals, height=5, s=8)
#       4 fig.set( xlabel = "True posture", ylabel = "Average_X_Motility_mg")
#       5 fig.set(title='Average_X_Motility_mg of missclassified samples')
#
# NameError: name 'plt' is not defined

# %%
plt.rcParams['figure.dpi'] = 100
plt.figure(figsize=(12, 6))
sns.set_theme(style='white')
sns.countplot(x="true_posture", hue="activity", data=residuals)
plt.legend(title='Number of missclassified samples by activity', fontsize=7)
plt.xlabel('True posture', fontsize=11);
plt.ylabel('Count', fontsize=11);
plt.title('Number of missclassified samples by activity', fontsize=14)
#plt.tick_params(axis='both', which='major', labelsize=14)

# %%
plt.rcParams['figure.dpi'] = 100
plt.figure(figsize=(18, 4))
sns.set_theme(style='white')
sns.countplot(x="activity", data=residuals)
#plt.legend(title='Number of missclassified samples by activity', fontsize=7)
plt.xlabel('True posture', fontsize=11);
plt.ylabel('Count', fontsize=11);
plt.title('Number of missclassified samples by activity', fontsize=14)
#plt.tick_params(axis='both', which='major', labelsize=14)

# %%
plt.rcParams['figure.dpi'] = 100
plt.figure(figsize=(5, 4))
sns.set_theme(style='white')
sns.countplot(x="true_posture", data=residuals)
#plt.legend(title='Number of missclassified samples by activity', fontsize=20)
plt.xlabel('True posture', fontsize=11);
plt.ylabel('Count', fontsize=11);
plt.title('Number of missclassified samples by activity', fontsize=12)
#plt.tick_params(axis='both', which='major', labelsize=14)

# %%
df_bar = residuals.copy()

# Draw bar plot
df_pivot = pd.pivot_table(
df_bar,
values="Average_HR_bpm",
index="pred_posture",
columns="activity",
aggfunc=np.mean
)

# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar", width = 0.7,  cmap = 'tab20', capsize=3)
plt.legend(loc=2, prop={'size': 8})
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(18, 10)
# Change the axes labels
ax.set_ylim(40, 140)
ax.set_yticks(np.arange(40, 140, step=10))
ax.set_xlabel("New class labels")
ax.set_ylabel("Average heart rate (bpm)")      
ax.xaxis.grid()
#ax.grid(which='major', axis='y', linestyle='-')
# Save image and return fig (don't change this part)
#fig.savefig('after activity selection.png',  bbox_inches='tight')

# %%
df_bar = residuals.copy()

# Draw bar plot
df_pivot = pd.pivot_table(
df_bar,
values="Average_X_Motility_mg",
index="pred_posture",
columns="activity",
aggfunc='count'
)

# Plot a bar chart using the DF
ax = df_pivot.plot(kind="bar", width = 0.7,  cmap = 'tab20', capsize=3)
plt.legend(loc=2, prop={'size': 8})
fig = ax.get_figure()
# Change the plot dimensions (width, height)
fig.set_size_inches(18, 10)
# Change the axes labels
ax.set_ylim(0, 50)
ax.set_yticks(np.arange(0, 50, step=5))
ax.set_xlabel("New class labels")
ax.set_ylabel("Average heart rate (bpm)")      
ax.xaxis.grid()
#ax.grid(which='major', axis='y', linestyle='-')
# Save image and return fig (don't change this part)
#fig.savefig('after activity selection.png',  bbox_inches='tight')

# %%
cols = ['Average_X_Motility_mg', 'Average_Y_Motility_mg', 'Min_HR_bpm', 'lagg_HR', 'Max_IBI_msec']
dat = df_new[cols]
datx = np.array(dat)
datx.shape

# %%
print(df_new.corr())

# %%
# plotting correlation heatmap
fig, ax = plt.subplots(figsize=(12,11))
dataplot = sns.heatmap(df_new.corr(), cmap="YlGnBu", annot=True, ax=ax)

# %% [raw]
# # get fold splitter
# kfold = KFold(n_splits=3, shuffle = False)
# # Dataframe with misclassified examples
# misclf_df = pd.DataFrame(
#     {
#         'folds' : np.zeros(x.shape[0]),
#         'is_misclassified' : np.zeros(x.shape[0])
#     },
# )
#
# for fold_n, (train_idx, test_idx) in enumerate(kfold.split(x, y)):
#
#     #get train/test split for current fold
#     X_train, y_train = x[train_idx], y[train_idx]
#     X_test, y_test = x[test_idx], y[test_idx]
#
#     # standardization
#     scaler = StandardScaler()
#     scaler.fit(X_train)
#     X_train_data_lr_1 = scaler.transform(X_train)
#     X_test_data_lr_1 = scaler.transform(X_test)
#
#         #SMOTE for data imbalance
#         #smote = SMOTE(sampling_strategy='not majority')
#         #X_train_data_lr_1, y_train_1  = smote.fit_resample(X_train_data_lr_1, train_y)
#         #logistic regression model
#     lr = LogisticRegression(random_state=55, class_weight = 'balanced')
#     lr.fit(X_train_data_lr_1, y_train)
#     y_pred_train = lr.predict(X_train_data_lr_1)
#     y_pred = lr.predict(X_test_data_lr_1)
#
#     # write results
#     misclf_df.loc[test_idx, 'folds'] = fold_n
#     misclf_df.loc[test_idx, 'is_misclassified'] = lr.predict(X_test_data_lr_1) != y_test
